# %% [markdown]
# # 🎬 Sentiment Analysis on Movie Reviews Practicle
#
# In this practicle, you will create ML models that predict sentiments on the  **IMDb movie reviews dataset**. To complete this task, you will be asked to complete the following sections:
#
# 1. Installing and importing libraries
# 2. Loading and exploring the dataset
# 3. Text preprocessing
# 4. Feature extraction (TF-IDF)
# 5. Training multiple classifiers
# 6. Evaluating model performance
# 7. Visualising results
#
#
# ---

# %% [markdown]
# ## Step 1 — Install Required Libraries
#
# Install the following libraries that will help you work on the dataset:
#
# A library for removing punctuation, numbers, or extra spaces from text
#
# A WordNet resource that groups words according to their meanings and relationships
#
# A library for loading/reading the data into a CSV
#
# A library for plotting a confusion matrix
#
# Install numpy version 1.26.4
#
# An NLP library for tokenization, stopword removal, and lemmatization
#
# A library for machine learning classification that will use three models: logistic regression, multinomial Naive Bayes, and Support Vector Machine (SVM), and provide evaluation results, a classification report, and a confusion matrix.
#
# Download NLTK resources for stopwords, punkt_tab,

# %% [markdown]
# ## Step 2 — Import Libraries
#
#
# Once all have been imported, print out ('All libraries imported successfully!')

# %% [markdown]
# ## Step 3 — Download the Dataset from kagglehub
#
# Download the IMDB Dataset of 50K Movie Reviews using [Kagglehub](https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews):
#
# Once downloaded, print the path of the downloaded file

# %% [markdown]
# ## Step 4 — Load and inspect the data head.
#
# Load the data into a csv and print out the first 5 lines.

# %% [markdown]
# ## Step 5 — Transform the categorical reviews into binary format.
#
# Create a new column called "sentiment_label" that will display positive labels from the "sentiment" column as 1, and negative labels as 0.
# Next, print out the shape and the first 5 lines of the df.

# %% [markdown]
# ## Question - What is the class distribution?
# Have a print out statement that shows the class distriution of the 'sentiment_label'

# %% [markdown]
# ## Step 6 — Text Preprocessing
#
# Perform core NLP text preprocessing techniques on the "review" text column, such as tokenization, stopword removal, noise removal, lowercasing, and lemmatization, and then print out the original reviews with the cleaned reviews. Name the column with the clean reviews'clean_review'.

# %% [markdown]
# ## Step 7 — TF-IDF Feature Extraction
#
# Split the data into testing and training using the [train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) function and apply [TF-IDF](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html) on your features 'clean_review'.
#
# Next, print out the number of features in the training sample, test samples, and vocubulary size.  You can choose max_features to be 10k in your TF-IDF vectoriser.

# %% [markdown]
# ## Step 8 — Train Multiple Models & find best model
#
# Train 3 scikit-learn classifiers (logistic regression, Naive Bayes, and linear SVM) that will detect sentiment in your extracted features. Print out the accuracies of each model and select/print out the best model with its accuracy. [Hint](https://www.geeksforgeeks.org/machine-learning/ensemble-methods-in-python/)

# %% [markdown]
# ## Question, what is the best performing model?

# %% [markdown]
# ## Step 9 — Classification report & Confusion matrix
#
# Print out the Classification report & Confusion matrix of the best model. [Hint](https://www.geeksforgeeks.org/machine-learning/confusion-matrix-machine-learning/)

# %% [markdown]
# ## Step 10 — Top Predictive Features
#
# Use a horizontal bar chat to display the 15 most important positive and gegative features learned by the logistic regression model
